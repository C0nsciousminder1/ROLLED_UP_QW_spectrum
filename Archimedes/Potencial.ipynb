# %% [markdown]
# # Effective Potential

# %%
#Librerias
import archimedes as ach
#import matplotlib.pyplot as plt
import pylab as plt
import scipy.interpolate as interpolate
import numpy as np
from scipy.integrate import simps
from filon import cos_integral
import scipy.interpolate as interpolate

# %%
nc0 = 5 # cicles number
ns0 = 20   # Subdivisiones en el intervalo de phi h
NP0 = 1000  # número de subsubintervalos para integrar
a0 = 2.0 
b0 = 2.0 
Long_arc_0,phi_0 =  ach.Arc_Lenght(ns0,nc0,NP0,a0,b0)
Ss= Long_arc_0

sf_0 = Long_arc_0[-1]

Nelectron=501

theta_0 = 0.0
F_grid_0 = np.array([1.0]) #np.linspace(0, 2.0, 50)
camp_F_0 = ach.CAMP(F_grid_0)
#---------------------------------------------------------------------------------------------------------------
SD_grid_0 =  np.array([ach.ssfi(7.5*np.pi,Long_arc_0,phi_0)]) #0.2*sf_0, 0.4*sf_0, 0.8*sf_0 
#---------------------------------------------------------------------------------------------------------------
VS_0,kindex_0,SE_grid_0,SD_SF_0,Ndonor_0,phie_0,NF_0 =  ach.int_vpot(sf_0,Nelectron,SD_grid_0,camp_F_0,theta_0,a0,b0,Long_arc_0,phi_0)
#COEF_0= ach.coef(VS_0,kindex_0,sf_0,NF_0,Nelectron,Ndonor_0)
#Ee_0,VecR_0,ND =  ach.schr(COEF_0,sf_0,NF_0,Nelectron,Ndonor_0)

# %%
SD_grid_0D =   np.linspace(0, sf_0, 20)  # 20 20 donor Positions
#---------------------------------------------------------------------------------------------------------------
VS_0D,kindex_0D,SE_grid_0D,SD_SF_0D,Ndonor_0D,phie_0D,NF_0D =  ach.int_vpot(sf_0,Nelectron,SD_grid_0D,camp_F_0,theta_0,a0,b0,Long_arc_0,phi_0)
COEF_0D= ach.coef(VS_0D,kindex_0D,sf_0,NF_0D,Nelectron,Ndonor_0D)
Ee_0D,VecR_0D,ND =  ach.schr(COEF_0D,sf_0,NF_0D,Nelectron,Ndonor_0D)

# %%
nc1 = 5 # cicles number
ns1 = 20   # Subdivisiones en el intervalo de phi h
NP1 = 1000  # número de subsubintervalos para integrar
a1 = 2.0 
b1 = 2.0 
Long_arc_1,phi_1 =  ach.Arc_Lenght(ns1,nc1,NP1,a1,b1)
Ss= Long_arc_1

sf_1 = Long_arc_1[-1]

Nelectron=501

theta_1 = 0.5*np.pi
F_grid_1 = np.array([1.0]) #np.linspace(0, 2.0, 50)
camp_F_1 = ach.CAMP(F_grid_1)
#---------------------------------------------------------------------------------------------------------------
SD_grid_1 =  np.array([ach.ssfi(10*np.pi,Long_arc_1,phi_1),ach.ssfi(4*np.pi,Long_arc_1,phi_1)]) #0.2*sf_0, 0.4*sf_0, 0.8*sf_0 
#---------------------------------------------------------------------------------------------------------------
VS_1,kindex_1,SE_grid_1,SD_SF_1,Ndonor_1,phie_1,NF_1 =  ach.int_vpot(sf_1,Nelectron,SD_grid_1,camp_F_1,theta_1,a1,b1,Long_arc_1,phi_1)
COEF_1= ach.coef(VS_1,kindex_1,sf_1,NF_1,Nelectron,Ndonor_1)
#Ee_0,VecR_0,ND =  ach.

# %%
SD_grid_1D =   np.linspace(0, sf_1, 20)  # 20 20 donor Positions
#---------------------------------------------------------------------------------------------------------------
VS_1D,kindex_1D,SE_grid_1D,SD_SF_1D,Ndonor_1D,phie_1D,NF_1D =  ach.int_vpot(sf_1,Nelectron,SD_grid_1D,camp_F_1,theta_1,a1,b1,Long_arc_1,phi_1)
COEF_1D= ach.coef(VS_1D,kindex_1D,sf_1,NF_1D,Nelectron,Ndonor_1D)
Ee_1D,VecR_1D,ND =  ach.schr(COEF_1D,sf_1,NF_1D,Nelectron,Ndonor_1D)

# %%
nc3 = 5 # cicles number
ns3 = 20   # Subdivisiones en el intervalo de phi h
NP3 = 1000  # número de subsubintervalos para integrar
a3 = 2.0 
b3 = 2.0 
Long_arc_3,phi_3 =  ach.Arc_Lenght(ns3,nc3,NP3,a3,b3)
Ss= Long_arc_3

sf_3 = Long_arc_3[-1]

Nelectron=501

theta_3 = np.pi
F_grid_3 = np.array([ 1.0 ]) #np.linspace(0, 2.0, 50)
camp_F_3 = ach.CAMP(F_grid_3)
#---------------------------------------------------------------------------------------------------------------
SD_grid_3 = np.array([ach.ssfi(6*np.pi,Long_arc_3,phi_3)])
#---------------------------------------------------------------------------------------------------------------
VS_3,kindex_3,SE_grid_3,SD_SF_3,Ndonor_3,phie_3,NF_3 =  ach.int_vpot(sf_3,Nelectron,SD_grid_3,camp_F_3,theta_3,a3,b3,Long_arc_3,phi_3)
#COEF_3= ach.coef(VS_3,kindex_3,sf_3,NF_3,Nelectron,Ndonor_3)
#Ee_0,VecR_0,ND =  ach.

# %%
SD_grid_3D =   np.linspace(0, sf_3, 20)  # 20 20 donor Positions
#---------------------------------------------------------------------------------------------------------------
VS_3D,kindex_3D,SE_grid_3D,SD_SF_3D,Ndonor_3D,phie_3D,NF_3D =  ach.int_vpot(sf_3,Nelectron,SD_grid_3D,camp_F_3,theta_3,a3,b3,Long_arc_3,phi_3)
COEF_3D= ach.coef(VS_3D,kindex_3D,sf_3,NF_3D,Nelectron,Ndonor_3D)
Ee_3D,VecR_3D,ND =  ach.schr(COEF_3D,sf_3,NF_3D,Nelectron,Ndonor_3D)

# %%
plt.plot(Ee_3D[0,:,0:10])

# %%
x =  SD_SF_0D
p=0

y0 =  Ee_0D[p,:,0]
y1 =  Ee_0D[p,:,1]
y2 =  Ee_0D[p,:,2]
y3 =  Ee_0D[p,:,3]
y4 =  Ee_0D[p,:,4]
y5 =  Ee_0D[p,:,5]
y6 =  Ee_0D[p,:,6]
y7 =  Ee_0D[p,:,7]
y8 =  Ee_0D[p,:,8]
y9 =  Ee_0D[p,:,9]
y10 = Ee_0D[p,:,10]

t0, c0, k0 = interpolate.splrep(x, y0, s=0, k=3)
t1, c1, k1 = interpolate.splrep(x, y1, s=0, k=3)
t2, c2, k2 = interpolate.splrep(x, y2, s=0, k=3)
t3, c3, k3 = interpolate.splrep(x, y3, s=0, k=3)
t4, c4, k4 = interpolate.splrep(x, y4, s=0, k=3)
t5, c5, k5 = interpolate.splrep(x, y5, s=0, k=3)
t6, c6, k6 = interpolate.splrep(x, y6, s=0, k=3)
t7, c7, k7 = interpolate.splrep(x, y7, s=0, k=3)
t8, c8, k8 = interpolate.splrep(x, y8, s=0, k=3)
t9, c9, k9 = interpolate.splrep(x, y9, s=0, k=3)
t10, c10, k10 = interpolate.splrep(x, y10, s=0, k=3)

N = 1000
xmin, xmax = x.min(), x.max()
xx0 = np.linspace(xmin, xmax, N)

spline0 = interpolate.BSpline(t0, c0, k0, extrapolate=False)
spline1 = interpolate.BSpline(t1, c1, k1, extrapolate=False)
spline2 = interpolate.BSpline(t2, c2, k2, extrapolate=False)
spline3 = interpolate.BSpline(t3, c3, k3, extrapolate=False)
spline4 = interpolate.BSpline(t4, c4, k4, extrapolate=False)
spline5 = interpolate.BSpline(t5, c5, k5, extrapolate=False)
spline6 = interpolate.BSpline(t6, c6, k6, extrapolate=False)
spline7 = interpolate.BSpline(t7, c7, k7, extrapolate=False)
spline8 = interpolate.BSpline(t8, c8, k8, extrapolate=False)
spline9 = interpolate.BSpline(t9, c9, k9, extrapolate=False)
spline10 = interpolate.BSpline(t10, c10, k10, extrapolate=False)


fig=plt.figure(figsize=(12,8) )#pi=1000)
plt.rc('text', usetex=True)
plt.rc('font', family='Serif')
ax = fig.add_subplot(1, 1, 1)

plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.ylabel(r'Energ\'ia' '($Ry^*$)' , labelpad=6,fontsize=22,fontweight='bold', horizontalalignment='center')           

plt.xlabel(r'Posici\'on Donadora (\textbf{$S_D$}/\textbf{$S_F$})',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')


#plt.xlim(0.1,0.9)
#plt.ylim(-1.1,0.1)

#plt.annotate('$\\theta\,   = \, \, \pi $', xy=(150, 85), xycoords='figure points',fontsize=24)

#plt.annotate(r'\textbf{$E_1$}', xy=(570, 110), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_2$}', xy=(575, 350), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_3$}', xy=(370, 355), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_4$}', xy=(670, 398), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_5$}', xy=(560, 398), xycoords='figure points',fontsize=15)

#plt.title('$Caso: R_0= 1 a_0^*$, $\Delta= 0.1 a_0^*$',loc='center',fontsize=20)

plt.plot(xx0, spline0(xx0), color='r', label= 'a = b = 2 $a_o^*$ \\ F = 0 kV/cm')
plt.plot(xx0, spline1(xx0), color='r' )
plt.plot(xx0, spline2(xx0) , color='r' ) #, label= 'b = 2 $a_o^*$')  
plt.plot(xx0, spline3(xx0) , color='r')
plt.plot(xx0, spline4(xx0) , color='r')
plt.plot(xx0, spline5(xx0) , color='r')
plt.plot(xx0, spline6(xx0) , color='r')
plt.plot(xx0, spline7(xx0) , color='r')
plt.plot(xx0, spline8(xx0) , color='r')
plt.plot(xx0, spline9(xx0) , color='r')
plt.plot(xx0, spline10(xx0), color='r' )#, label= 'F = 0.5 kV/cm')

# %%
x =  SD_SF_1D
p=0

y0 =  Ee_1D[p,:,0]
y1 =  Ee_1D[p,:,1]
y2 =  Ee_1D[p,:,2]
y3 =  Ee_1D[p,:,3]
y4 =  Ee_1D[p,:,4]
y5 =  Ee_1D[p,:,5]
y6 =  Ee_1D[p,:,6]
y7 =  Ee_1D[p,:,7]
y8 =  Ee_1D[p,:,8]
y9 =  Ee_1D[p,:,9]
y10 =  Ee_1D[p,:,10]

t0, c0, k0 = interpolate.splrep(x, y0, s=0, k=3)
t1, c1, k1 = interpolate.splrep(x, y1, s=0, k=3)
t2, c2, k2 = interpolate.splrep(x, y2, s=0, k=3)
t3, c3, k3 = interpolate.splrep(x, y3, s=0, k=3)
t4, c4, k4 = interpolate.splrep(x, y4, s=0, k=3)
t5, c5, k5 = interpolate.splrep(x, y5, s=0, k=3)
t6, c6, k6 = interpolate.splrep(x, y6, s=0, k=3)
t7, c7, k7 = interpolate.splrep(x, y7, s=0, k=3)
t8, c8, k8 = interpolate.splrep(x, y8, s=0, k=3)
t9, c9, k9 = interpolate.splrep(x, y9, s=0, k=3)
t10, c10, k10 = interpolate.splrep(x, y10, s=0, k=3)

N = 1000
xmin, xmax = x.min(), x.max()
xx1 = np.linspace(xmin, xmax, N)

s1pline0 = interpolate.BSpline(t0, c0, k0, extrapolate=False)
s1pline1 = interpolate.BSpline(t1, c1, k1, extrapolate=False)
s1pline2 = interpolate.BSpline(t2, c2, k2, extrapolate=False)
s1pline3 = interpolate.BSpline(t3, c3, k3, extrapolate=False)
s1pline4 = interpolate.BSpline(t4, c4, k4, extrapolate=False)
s1pline5 = interpolate.BSpline(t5, c5, k5, extrapolate=False)
s1pline6 = interpolate.BSpline(t6, c6, k6, extrapolate=False)
s1pline7 = interpolate.BSpline(t7, c7, k7, extrapolate=False)
s1pline8 = interpolate.BSpline(t8, c8, k8, extrapolate=False)
s1pline9 = interpolate.BSpline(t9, c9, k9, extrapolate=False)
s1pline10 = interpolate.BSpline(t10, c10, k10, extrapolate=False)


fig=plt.figure(figsize=(12,8) )#pi=1000)
plt.rc('text', usetex=True)
plt.rc('font', family='Serif')
ax = fig.add_subplot(1, 1, 1)

plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.ylabel(r'Energ\'ia' '($Ry^*$)' , labelpad=6,fontsize=22,fontweight='bold', horizontalalignment='center')           

plt.xlabel(r'Posici\'on Donadora (\textbf{$S_D$}/\textbf{$S_F$})',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')


plt.xlim(0.1,0.9)
#plt.ylim(-1.1,0.1)

#plt.annotate('$\\theta\,   = \, \, \pi $', xy=(150, 85), xycoords='figure points',fontsize=24)

#plt.annotate(r'\textbf{$E_1$}', xy=(570, 110), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_2$}', xy=(575, 350), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_3$}', xy=(370, 355), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_4$}', xy=(670, 398), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_5$}', xy=(560, 398), xycoords='figure points',fontsize=15)

#plt.title('$Caso: R_0= 1 a_0^*$, $\Delta= 0.1 a_0^*$',loc='center',fontsize=20)

plt.plot(xx1, s1pline0(xx1), color='r', label= 'a = b = 2 $a_o^*$ \\ F = 0 kV/cm')
plt.plot(xx1, s1pline1(xx1), color='r' ) #, label= 'a = 2 $a_o^*$')  
plt.plot(xx1, s1pline2(xx1) , color='r' ) #, label= 'b = 2 $a_o^*$')  
plt.plot(xx1, s1pline3(xx1) , color='r')
plt.plot(xx1, s1pline4(xx1) , color='r')
plt.plot(xx1, s1pline5(xx1) , color='r')
plt.plot(xx1, s1pline6(xx1) , color='r')
plt.plot(xx1, s1pline7(xx1) , color='r')
plt.plot(xx1, s1pline8(xx1) , color='r')
plt.plot(xx1, s1pline9(xx1) , color='r')
plt.plot(xx1, s1pline10(xx1), color='r' )#, label= 'F = 0.5 kV/cm')

# %%
x =  SD_SF_3D
p=0

y0 =  Ee_3D[p,:,0]
y1 =  Ee_3D[p,:,1]
y2 =  Ee_3D[p,:,2]
y3 =  Ee_3D[p,:,3]
y4 =  Ee_3D[p,:,4]
y5 =  Ee_3D[p,:,5]
y6 =  Ee_3D[p,:,6]
y7 =  Ee_3D[p,:,7]
y8 =  Ee_3D[p,:,8]
y9 =  Ee_3D[p,:,9]
y10 = Ee_3D[p,:,10]

t0, c0, k0 = interpolate.splrep(x, y0, s=0, k=3)
t1, c1, k1 = interpolate.splrep(x, y1, s=0, k=3)
t2, c2, k2 = interpolate.splrep(x, y2, s=0, k=3)
t3, c3, k3 = interpolate.splrep(x, y3, s=0, k=3)
t4, c4, k4 = interpolate.splrep(x, y4, s=0, k=3)
t5, c5, k5 = interpolate.splrep(x, y5, s=0, k=3)
t6, c6, k6 = interpolate.splrep(x, y6, s=0, k=3)
t7, c7, k7 = interpolate.splrep(x, y7, s=0, k=3)
t8, c8, k8 = interpolate.splrep(x, y8, s=0, k=3)
t9, c9, k9 = interpolate.splrep(x, y9, s=0, k=3)
t10, c10, k10 = interpolate.splrep(x, y10, s=0, k=3)

N = 1000
xmin, xmax = x.min(), x.max()
xx2 = np.linspace(xmin, xmax, N)

s2pline0 = interpolate.BSpline(t0, c0, k0, extrapolate=False)
s2pline1 = interpolate.BSpline(t1, c1, k1, extrapolate=False)
s2pline2 = interpolate.BSpline(t2, c2, k2, extrapolate=False)
s2pline3 = interpolate.BSpline(t3, c3, k3, extrapolate=False)
s2pline4 = interpolate.BSpline(t4, c4, k4, extrapolate=False)
s2pline5 = interpolate.BSpline(t5, c5, k5, extrapolate=False)
s2pline6 = interpolate.BSpline(t6, c6, k6, extrapolate=False)
s2pline7 = interpolate.BSpline(t7, c7, k7, extrapolate=False)
s2pline8 = interpolate.BSpline(t8, c8, k8, extrapolate=False)
s2pline9 = interpolate.BSpline(t9, c9, k9, extrapolate=False)
s2pline10 = interpolate.BSpline(t10, c10, k10, extrapolate=False)


fig=plt.figure(figsize=(12,8) )#pi=1000)
plt.rc('text', usetex=True)
plt.rc('font', family='Serif')
ax = fig.add_subplot(1, 1, 1)

plt.rc('axes', labelsize=20)
plt.rc('xtick', labelsize=20)
plt.rc('ytick', labelsize=20)

plt.ylabel(r'Energ\'ia' '($Ry^*$)' , labelpad=6,fontsize=22,fontweight='bold', horizontalalignment='center')           

plt.xlabel(r'Posici\'on Donadora (\textbf{$S_D$}/\textbf{$S_F$})',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')


plt.xlim(0.1,0.9)
#plt.ylim(-1.1,0.1)

#plt.annotate('$\\theta\,   = \, \, \pi $', xy=(150, 85), xycoords='figure points',fontsize=24)

#plt.annotate(r'\textbf{$E_1$}', xy=(570, 110), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_2$}', xy=(575, 350), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_3$}', xy=(370, 355), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_4$}', xy=(670, 398), xycoords='figure points',fontsize=15)
#plt.annotate(r'\textbf{$E_5$}', xy=(560, 398), xycoords='figure points',fontsize=15)

#plt.title('$Caso: R_0= 1 a_0^*$, $\Delta= 0.1 a_0^*$',loc='center',fontsize=20)

plt.plot(xx2, s2pline0(xx2), color='r', label= 'a = b = 2 $a_o^*$ \\ F = 0 kV/cm')
plt.plot(xx2, s2pline1(xx2), color='r' ) #, label= 'a = 2 $a_o^*$')  
plt.plot(xx2, s2pline2(xx2) , color='r' ) #, label= 'b = 2 $a_o^*$')  
plt.plot(xx2, s2pline3(xx2) , color='r')
plt.plot(xx2, s2pline4(xx2) , color='r')
plt.plot(xx2, s2pline5(xx2) , color='r')
plt.plot(xx2, s2pline6(xx2) , color='r')
plt.plot(xx2, s2pline7(xx2) , color='r')
plt.plot(xx2, s2pline8(xx2) , color='r')
plt.plot(xx2, s2pline9(xx2) , color='r')
plt.plot(xx2, s2pline10(xx2), color='r' )#, label= 'F = 0.5 kV/cm')

# %%
fig = plt.figure(figsize=(18,10))

fig.subplots_adjust(hspace=0.18, wspace=0.2)
plt.rc('text', usetex=True)
plt.rc('font', family='serif')

ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)
ax4 = fig.add_subplot(2, 2, 4)

ax1.plot(SE_grid_0, VS_0[0,0,:], color='r')#, markersize=4, alpha=0.4)
#ax2.plot(xx, E_0D[:], color='r')#, markersize=4, alpha=0.4)


ax2.plot(xx0, spline0(xx0), color='r', label= 'a = b = 2 $a_o^*$ \\ F = 0 kV/cm')
ax2.plot(xx0, spline1(xx0), color='r' ) #, label= 'a = 2 $a_o^*$')  
ax2.plot(xx0, spline2(xx0) , color='r' ) #, label= 'b = 2 $a_o^*$')  
ax2.plot(xx0, spline3(xx0) , color='r')
ax2.plot(xx0, spline4(xx0) , color='r')
ax2.plot(xx0, spline5(xx0) , color='r')
ax2.plot(xx0, spline6(xx0) , color='r')
ax2.plot(xx0, spline7(xx0) , color='r')
ax2.plot(xx0, spline8(xx0) , color='r')
ax2.plot(xx0, spline9(xx0) , color='r')
ax2.plot(xx0, spline10(xx0), color='r' )




ax3.plot(SE_grid_1, VS_1[0,0,:], color='black')#, markersize=4, alpha=0.4)
#ax4.plot(SD_SF_1D, Ee_1D[0,:,0:10], color='black')#, markersize=4, alpha=0.4)

ax4.plot(xx1, s1pline0(xx),  color='black')#, markersize=4, alpha=0.4)
ax4.plot(xx1, s1pline1(xx), color='black')#, label= 'a = 2 $a_o^*$')  
ax4.plot(xx1, s1pline2(xx) , color='black') #, label= 'b = 2 $a_o^*$')  
ax4.plot(xx1, s1pline3(xx) , color='black')
ax4.plot(xx1, s1pline4(xx) , color='black')
ax4.plot(xx1, s1pline5(xx) , color='black')
ax4.plot(xx1, s1pline6(xx) , color='black')
ax4.plot(xx1, s1pline7(xx) , color='black')
ax4.plot(xx1, s1pline8(xx) , color='black')
ax4.plot(xx1, s1pline9(xx) , color='black')
ax4.plot(xx1, s1pline10(xx), color='black')

ax4.axvline(0.6, color='grey', linestyle='--')
ax2.axvline(0.6, color='grey', linestyle='--')
plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

ax1.set_ylim(-4,0.3)
#ax2.set_ylim(-1.2,0)
ax3.set_ylim(-4,0.3)
#ax4.set_ylim(-1.2,0)


ax1.set_xlim(0,SE_grid_0.max())
ax2.set_xlim(0.1,0.9)
ax3.set_xlim(0,SE_grid_1.max())
ax4.set_xlim(0.1,0.9)


ax3.set_xlabel(r' S ($a_o^*$) ', labelpad=10,fontsize=20,fontweight='bold', horizontalalignment='center')           
ax4.set_xlabel(r' Posici\'on relativa de la Donadora (S$_D$/S$_F$) ', labelpad=10,fontsize=20,fontweight='bold', horizontalalignment='center')           


ax1.set_ylabel(r'$V(s,z=0)$\, ($Ry^*$)',labelpad=8,fontsize=22,fontweight='bold', horizontalalignment ='center')
ax2.set_ylabel(r'Energ\'ia ($Ry^*$)',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')
ax3.set_ylabel(r'$V(s,z=0)$ \, ($Ry^*$)',labelpad=8,fontsize=22,fontweight='bold', horizontalalignment ='center')
ax4.set_ylabel(r' Energ\'ia ($Ry^*$)',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')
ax1.legend(["a = b = 2 \, \,  ($a_o^*$)"], loc=(3),fontsize=15)
ax3.legend(["a = 2 \\ b = 0.5 \, \,  ($a_o^*$)"], loc=(3),fontsize=15)
#ax3.legend(["F = 0. \,\, \quad kV/cm", "a = b = 2 \, \,  $a_o^*$", "F = 1 \,\, \quad kV/cm"], loc=(1),fontsize=15)

#plt.savefig('Arc_VESF.pdf',format='pdf', dpi=1000,bbox_inches="tight")

# %%
fig, (ax2, ax4) = plt.subplots(1, 2, sharex=True, figsize=(20,6))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
ax2.plot(xx0, spline0(xx0), color='r', label= 'a = b = 2 $a_o^*$ \\ F = 0 kV/cm')
ax2.plot(xx0, spline1(xx0), color='r' ) #, label= 'a = 2 $a_o^*$')  
ax2.plot(xx0, spline2(xx0) , color='r' ) #, label= 'b = 2 $a_o^*$')  
ax2.plot(xx0, spline3(xx0) , color='r')
ax2.plot(xx0, spline4(xx0) , color='r')
ax2.plot(xx0, spline5(xx0) , color='r')
ax2.plot(xx0, spline6(xx0) , color='r')
ax2.plot(xx0, spline7(xx0) , color='r')
ax2.plot(xx0, spline8(xx0) , color='r')
ax2.plot(xx0, spline9(xx0) , color='r')
ax2.plot(xx0, spline10(xx0), color='r' )
plt.yticks(np.arange(-1.6,0.2, 0.4))



ax4.plot(xx1, s1pline0(xx),  color='black')#, markersize=4, alpha=0.4)
ax4.plot(xx1, s1pline1(xx), color='black')#, label= 'a = 2 $a_o^*$')  
ax4.plot(xx1, s1pline2(xx) , color='black') #, label= 'b = 2 $a_o^*$')  
ax4.plot(xx1, s1pline3(xx) , color='black')
ax4.plot(xx1, s1pline4(xx) , color='black')
ax4.plot(xx1, s1pline5(xx) , color='black')
ax4.plot(xx1, s1pline6(xx) , color='black')
ax4.plot(xx1, s1pline7(xx) , color='black')
ax4.plot(xx1, s1pline8(xx) , color='black')
ax4.plot(xx1, s1pline9(xx) , color='black')
ax4.plot(xx1, s1pline10(xx), color='black')

ax2.axvline(0.15, color='grey', linestyle='--')
ax2.axvline(0.32, color='grey', linestyle='--')
ax2.axvline(0.55, color='grey', linestyle='--')
ax2.axvline(0.835, color='grey', linestyle='--')

ax4.axvline(0.15, color='grey', linestyle='--')
ax4.axvline(0.32, color='grey', linestyle='--')
ax4.axvline(0.55, color='grey', linestyle='--')
ax4.axvline(0.835, color='grey', linestyle='--')
#array([0.15046645, 0.32191641, 0.5503739 , 0.8358638 ])
plt.rc('xtick', labelsize=22) 
plt.rc('ytick', labelsize=22) 

#ax1.set_ylim(-4,0.3)
ax2.set_ylim(-1.6,0)
#ax3.set_ylim(-4,0.3)
#ax4.set_ylim(-1.5,0)


#ax1.set_xlim(0,SE_grid_0.max())
ax2.set_xlim(0.15,0.9)
#ax3.set_xlim(0,SE_grid_1.max())
ax4.set_xlim(0.15,0.89)

#ax2.yaxis.set_ticks(np.arange((-1.5,0.0, 0.25)))
#ax4.yaxis.set_ticks(np.arange((-1.5,0.0, 0.25)))
start= -1.6
end = 0.2#ax2.get_xlim()
ax2.yaxis.set_ticks(np.arange(start, end, 0.4))

plt.yticks(np.arange(-1.6,0.2, 0.4))

ax2.set_xlabel(r' Posici\'on de la Donadora (S$_D$/S$_F$)  ', labelpad=10,fontsize=20,fontweight='bold', horizontalalignment='center')           
ax4.set_xlabel(r' Posici\'on de la Donadora (S$_D$/S$_F$) ', labelpad=10,fontsize=20,fontweight='bold', horizontalalignment='center')           


#ax1.set_ylabel(r'$V(s,z=0)$\, ($Ry^*$)',labelpad=8,fontsize=22,fontweight='bold', horizontalalignment ='center')
ax2.set_ylabel(r'Energ\'ia ($Ry^*$)',labelpad=8,fontsize=24,fontweight='bold', horizontalalignment ='center')
#ax3.set_ylabel(r'$V(s,z=0)$ \, ($Ry^*$)',labelpad=8,fontsize=22,fontweight='bold', horizontalalignment ='center')
#ax4.set_ylabel(r' Energ\'ia ($Ry^*$)',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')
#ax1.legend(["a = b = 2 \, \,  ($a_o^*$)"], loc=(3),fontsize=15)
#ax3.legend(["a = 2 \\ b = 0.5 \, \,  ($a_o^*$)"], loc=(3),fontsize=15)
ax2.legend(["F = 0.25 \,\, kV/cm"], loc=(3),fontsize=20)
ax4.legend(["F = 0.5 \,\, kV/cm"], loc=(3),fontsize=20)

#plt.savefig('Arc_E_SD.pdf',format='pdf', dpi=1000,bbox_inches="tight")

# %%
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(6,16))
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
 

ax1.plot(xx0, spline0(xx0) )
ax1.plot(xx0, spline1(xx0) ) 
ax1.plot(xx0, spline2(xx0)  )
ax1.plot(xx0, spline3(xx0) )
ax1.plot(xx0, spline4(xx0) )
ax1.plot(xx0, spline5(xx0)  )
ax1.plot(xx0, spline6(xx0)  )
ax1.plot(xx0, spline7(xx0)  )
ax1.plot(xx0, spline8(xx0)  )
ax1.plot(xx0, spline9(xx0)  )
ax1.plot(xx0, spline10(xx0)  )


ax2.plot(xx1, s1pline0(xx1) )
ax2.plot(xx1, s1pline1(xx1) ) #, color='black')#, label= 'a = 2 $a_o^*$')  
ax2.plot(xx1, s1pline2(xx1) )#, color='black') #, label= 'b = 2 $a_o^*$')  
ax2.plot(xx1, s1pline3(xx1))# , color='black')
ax2.plot(xx1, s1pline4(xx1) )#, color='black')
ax2.plot(xx1, s1pline5(xx1) )#, color='black')
ax2.plot(xx1, s1pline6(xx1) )#, , color='black')
ax2.plot(xx1, s1pline7(xx1)  )#,, color='black')
ax2.plot(xx1, s1pline8(xx1)  )#,, color='black')
ax2.plot(xx1, s1pline9(xx1)  )#,, color='black')
ax2.plot(xx1, s1pline10(xx1)  )#,, color='black')

ax3.plot(xx2, s2pline0(xx2)  )#,, color='r', label= 'a = b = 2 $a_o^*$ \\ F = 0 kV/cm')
ax3.plot(xx2, s2pline1(xx2)  )#,, color='r' ) #, label= 'a = 2 $a_o^*$')  
ax3.plot(xx2, s2pline2(xx2)  )#,, color='r' ) #, label= 'b = 2 $a_o^*$')  
ax3.plot(xx2, s2pline3(xx2)  )#,, color='r')
ax3.plot(xx2, s2pline4(xx2)  )#,, color='r')
ax3.plot(xx2, s2pline5(xx2)  )#,, color='r')
ax3.plot(xx2, s2pline6(xx2)  )#,, color='r')
ax3.plot(xx2, s2pline7(xx2)  )#,, color='r')
ax3.plot(xx2, s2pline8(xx2) )#, , color='r')
ax3.plot(xx2, s2pline9(xx2)  )#,, color='r')
ax3.plot(xx2, s2pline10(xx2) )#,, color='r' )



plt.rc('xtick', labelsize=20) 
plt.rc('ytick', labelsize=20) 

ax1.set_ylim(-2,-0.3)
ax2.set_ylim(-2,-0.3)
ax3.set_ylim(-2,-0.3)



ax1.set_xlim(0.1,0.9)
ax2.set_xlim(0.1,0.9)
#ax3.set_xlim(0,SE_grid_1.max())
ax3.set_xlim(0.1,0.9)


ax3.set_xlabel(r' Posici\'on de la Donadora (S$_D$/S$_F$) ', labelpad=8,fontsize=22,fontweight='bold', horizontalalignment='center')           
ax1.set_ylabel(r' Energ\'ia ($Ry^*$)',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')
ax2.set_ylabel(r'Energ\'ia ($Ry^*$)',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')
ax3.set_ylabel(r' Energ\'ia ($Ry^*$)',labelpad=6,fontsize=22,fontweight='bold', horizontalalignment ='center')

ax1.legend(["F = 1 \,\,  kV/cm","$\\theta = 0$ "], loc=(3),fontsize=15)
ax2.legend(["F = 1 \,\,  kV/cm","$\\theta = \pi/2 $ "], loc=(3),fontsize=15)
ax3.legend(["F = 1 \,\,  kV/cm", "$\\theta= \pi$ "], loc=(3),fontsize=15)
#ax3.legend(["F = 0. \,\, \quad kV/cm", "a = b = 2 \, \,  $a_o^*$", "F = 1 \,\, \quad kV/cm"], loc=(1),fontsize=15)

plt.savefig('Arc_Ftheta_spectrum.pdf',format='pdf', dpi=1000,bbox_inches="tight")

# %%
x = SE_grid_0
#----------------#-----------
y0_f0 =  VS_0[0,0,:]
y0_f1 =  VS_0[1,0,:]
y0_f2 =  VS_0[2,0,:]
y0_f3 =  VS_0[3,0,:]
y0_f4 =  VS_0[4,0,:]
#----------------#-----------
y1_f0 =  VS_0[0,1,:]
y1_f1 =  VS_0[1,1,:]
y1_f2 =  VS_0[2,1,:]
y1_f3 =  VS_0[3,1,:]
y1_f4 =  VS_0[4,1,:]
#----------------#-----------
y2_f0 =  VS_0[0,2,:]
y2_f1 =  VS_0[1,2,:]
y2_f2 =  VS_0[2,2,:]
y2_f3 =  VS_0[3,2,:]
y2_f4 =  VS_0[4,2,:]

# %%
data = np.column_stack((x,
#-------- Donor Position 0.2*SF----------
y0_f0,   # F = 0
y0_f1,   # F = 0.25
y0_f2,   # F = 0.5
y0_f3,   # F = 1
y0_f4,   # F = 2 
#--------Donor Position 0.5*SF ---------              
y1_f0,
y1_f1,
y1_f2,
y1_f3,
y1_f4, 
#--------Donor Position 0.8*SF ---------
y2_f0,
y2_f1,
y2_f2,
y2_f3,
y2_f4))
np.savetxt('Vpot.dat', data)
